# %% [markdown]
# ## Importing the libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Importing the dataset

# %%
df = pd.read_csv("retail_sales_dataset.csv", sep = ",", encoding="Latin-1")
df
# Out:
#      Transaction ID        Date Customer ID  Gender  Age Product Category  \
# 0                 1  2023-11-24     CUST001    Male   34           Beauty
# 1                 2  2023-02-27     CUST002  Female   26         Clothing
# 2                 3  2023-01-13     CUST003    Male   50      Electronics
# 3                 4  2023-05-21     CUST004    Male   37         Clothing
# 4                 5  2023-05-06     CUST005    Male   30           Beauty
# ..              ...         ...         ...     ...  ...              ...
# 995             996  2023-05-16     CUST996    Male   62         Clothing
# 996             997  2023-11-17     CUST997    Male   52           Beauty
# 997             998  2023-10-29     CUST998  Female   23           Beauty
# 998             999  2023-12-05     CUST999  Female   36      Electronics
# 999            1000  2023-04-12    CUST1000    Male   47      Electronics
#
#      Quantity  Price per Unit  Total Amount
# ...

# %%
df.shape
# Out:
# (1000, 9)

# %%
df.head()
# Out:
#    Transaction ID        Date Customer ID  Gender  Age Product Category  \
# 0               1  2023-11-24     CUST001    Male   34           Beauty
# 1               2  2023-02-27     CUST002  Female   26         Clothing
# 2               3  2023-01-13     CUST003    Male   50      Electronics
# 3               4  2023-05-21     CUST004    Male   37         Clothing
# 4               5  2023-05-06     CUST005    Male   30           Beauty
#
#    Quantity  Price per Unit  Total Amount
# 0         3              50           150
# 1         2             500          1000
# 2         1              30            30
# 3         1             500           500
# 4         2              50           100

# %%
df.describe()
# Out:
#        Transaction ID         Age     Quantity  Price per Unit  Total Amount
# count     1000.000000  1000.00000  1000.000000     1000.000000   1000.000000
# mean       500.500000    41.39200     2.514000      179.890000    456.000000
# std        288.819436    13.68143     1.132734      189.681356    559.997632
# min          1.000000    18.00000     1.000000       25.000000     25.000000
# 25%        250.750000    29.00000     1.000000       30.000000     60.000000
# 50%        500.500000    42.00000     3.000000       50.000000    135.000000
# 75%        750.250000    53.00000     4.000000      300.000000    900.000000
# max       1000.000000    64.00000     4.000000      500.000000   2000.000000

# %%
df.tail(1)
# Out:
#      Transaction ID        Date Customer ID Gender  Age Product Category  \
# 999            1000  2023-04-12    CUST1000   Male   47      Electronics
#
#      Quantity  Price per Unit  Total Amount
# 999         4              30           120

# %%
df.dtypes
# Out:
# Transaction ID       int64
# Date                object
# Customer ID         object
# Gender              object
# Age                  int64
# Product Category    object
# Quantity             int64
# Price per Unit       int64
# Total Amount         int64
# dtype: object

# %%
pd.options.display.max_rows = 9999

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Transaction ID    1000 non-null   int64
#  1   Date              1000 non-null   object
#  2   Customer ID       1000 non-null   object
#  3   Gender            1000 non-null   object
#  4   Age               1000 non-null   int64
#  5   Product Category  1000 non-null   object
#  6   Quantity          1000 non-null   int64
#  7   Price per Unit    1000 non-null   int64
#  8   Total Amount      1000 non-null   int64
# dtypes: int64(5), object(4)
# memory usage: 70.4+ KB

# %% [markdown]
# ## Cleaning the dataset

# %%
df1 = df.drop(["Transaction ID"], axis = 1)
df1
# Out:
#            Date Customer ID  Gender  Age Product Category  Quantity  \
# 0    2023-11-24     CUST001    Male   34           Beauty         3
# 1    2023-02-27     CUST002  Female   26         Clothing         2
# 2    2023-01-13     CUST003    Male   50      Electronics         1
# 3    2023-05-21     CUST004    Male   37         Clothing         1
# 4    2023-05-06     CUST005    Male   30           Beauty         2
# 5    2023-04-25     CUST006  Female   45           Beauty         1
# 6    2023-03-13     CUST007    Male   46         Clothing         2
# 7    2023-02-22     CUST008    Male   30      Electronics         4
# 8    2023-12-13     CUST009    Male   63      Electronics         2
# 9    2023-10-07     CUST010  Female   52         Clothing         4
# 10   2023-02-14     CUST011    Male   23         Clothing         2
# 11   2023-10-30     CUST012    Male   35           Beauty         3
# 12   2023-08-05     CUST013    Male   22      Electronics         3
# ...

# %%
df1.index = df1["Customer ID"]
df1
# Out:
#                    Date Customer ID  Gender  Age Product Category  Quantity  \
# Customer ID
# CUST001      2023-11-24     CUST001    Male   34           Beauty         3
# CUST002      2023-02-27     CUST002  Female   26         Clothing         2
# CUST003      2023-01-13     CUST003    Male   50      Electronics         1
# CUST004      2023-05-21     CUST004    Male   37         Clothing         1
# CUST005      2023-05-06     CUST005    Male   30           Beauty         2
# CUST006      2023-04-25     CUST006  Female   45           Beauty         1
# CUST007      2023-03-13     CUST007    Male   46         Clothing         2
# CUST008      2023-02-22     CUST008    Male   30      Electronics         4
# CUST009      2023-12-13     CUST009    Male   63      Electronics         2
# CUST010      2023-10-07     CUST010  Female   52         Clothing         4
# CUST011      2023-02-14     CUST011    Male   23         Clothing         2
# ...

# %%
df2 = df1.drop(["Customer ID"], axis = 1)
df2
# Out:
#                    Date  Gender  Age Product Category  Quantity  \
# Customer ID
# CUST001      2023-11-24    Male   34           Beauty         3
# CUST002      2023-02-27  Female   26         Clothing         2
# CUST003      2023-01-13    Male   50      Electronics         1
# CUST004      2023-05-21    Male   37         Clothing         1
# CUST005      2023-05-06    Male   30           Beauty         2
# CUST006      2023-04-25  Female   45           Beauty         1
# CUST007      2023-03-13    Male   46         Clothing         2
# CUST008      2023-02-22    Male   30      Electronics         4
# CUST009      2023-12-13    Male   63      Electronics         2
# CUST010      2023-10-07  Female   52         Clothing         4
# CUST011      2023-02-14    Male   23         Clothing         2
# CUST012      2023-10-30    Male   35           Beauty         3
# CUST013      2023-08-05    Male   22      Electronics         3
# ...

# %%
df3 = df2.drop(["Age", "Product Category", "Date", "Gender"], axis = 1)
df3
# Out:
#              Quantity  Price per Unit  Total Amount
# Customer ID
# CUST001             3              50           150
# CUST002             2             500          1000
# CUST003             1              30            30
# CUST004             1             500           500
# CUST005             2              50           100
# CUST006             1              30            30
# CUST007             2              25            50
# CUST008             4              25           100
# CUST009             2             300           600
# CUST010             4              50           200
# CUST011             2              50           100
# CUST012             3              25            75
# CUST013             3             500          1500
# CUST014             4              30           120
# CUST015             4             500          2000
# CUST016             3             500          1500
# CUST017             4              25           100
# ...

# %%
df2.isnull().sum()
# Out:
# Date                0
# Gender              0
# Age                 0
# Product Category    0
# Quantity            0
# Price per Unit      0
# Total Amount        0
# dtype: int64

# %% [markdown]
# ### Dealing with outliers

# %%
quantity = df2["Quantity"]
price = df2["Price per Unit"]
amount = df2["Total Amount"]

data = list([quantity, price, amount])

# %%
sns.boxplot(data)
plt.grid(True)
plt.xlabel("Quantity, Price per Unit, Total Amount")
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# ### Checking for Dupicates

# %%
df2.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## Exploratory Data Analysis

# %%
df2.corr()
# Out:
# C:\Program Files\KMSpico\temp\ipykernel_11628\1778878097.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df2.corr()
#                      Age  Quantity  Price per Unit  Total Amount
# Age             1.000000 -0.023737       -0.038423     -0.060568
# Quantity       -0.023737  1.000000        0.017501      0.373707
# Price per Unit -0.038423  0.017501        1.000000      0.851925
# Total Amount   -0.060568  0.373707        0.851925      1.000000

# %% [markdown]
# ### Total Amount of Sales For Each Quantity

# %%
category = df2["Product Category"]

plt.figure(figsize = (10,10))
plt.barh(category, amount, color = ("green"))
plt.xlabel("Total Amount")
plt.ylabel("Product Category")
plt.grid(True)
plt.title("Total Amount of Sales For Each Quantity")
# Out:
# Text(0.5, 1.0, 'Total Amount of Sales For Each Quantity')

# %% [markdown]
# ### Histogram for The Customers' Age

# %%
plt.figure(figsize = (7,7))
sns.histplot(df2["Age"], color = "red", bins = 10)
plt.grid(True)
plt.title("Customer Age Frequency")
# Out:
# Text(0.5, 1.0, 'Customer Age Frequency')

# %% [markdown]
# ### Scatterplot for Amount, Quantity against Age

# %%
x = df2["Age"]
y = amount
z = price

plt.figure(figsize = (10,10))
plt.scatter(x, y, s= 300)
plt.scatter(x, z, s=200)
plt.legend(["y", "z"])
plt.xlabel("Age")
plt.ylabel("Amount and Price Per Unit")
plt.grid(True)
plt.title("Comparison between Amount and Price Per Unit against Age")
plt.show()

# %% [markdown]
# ### Violin plot for Quantity

# %%
plt.figure(figsize=(8,8))
plt.violinplot(quantity, showmeans=True, showmedians=True)
plt.grid(True)
plt.xlabel("Quanity")
plt.ylabel("Count")
plt.title("Quanity")
plt.show()

# %% [markdown]
# ## Coming up with an SVC Model

# %%
import sklearn

# %%
from sklearn import svm

# %%
from sklearn.svm import SVC

# %%
X = df3.drop(["Total Amount"], axis = 1)
y = df3["Total Amount"]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train,y_test = train_test_split(X, y, test_size=0.2, random_state =0)

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc= StandardScaler()

# %%
X_train = sc.fit_transform(X_train)
X_test =sc.transform(X_test)

# %%
clf = svm.SVC()

# %%
clf.fit(X_train, y_train)
# Out:
# SVC()

# %% [markdown]
# ### Predicting the model using the classifier

# %%
pred_clf = clf.predict(X_test)

# %%
pred_clf
# Out:
# array([1000,  200, 1000,   90, 1500,  200,  500,   50,   50,  500,  200,
#        1200,  200,  300,   50,  900,   50,   50, 2000, 1500,   90, 1200,
#         200,  200,   50, 2000, 1200, 1000,  500, 1000,  200, 1500,  200,
#          50,  900,   50,   50,   50,   50,   50,   90,   90, 1500,  200,
#         300,  500,  200, 1200,   90,   50, 1200, 1200,   50,  200,   50,
#         200,   50,  200,   90, 1200,  500,   90,   50, 1000,  200,  200,
#         900,  200, 2000, 2000,   50,  200,  300,  900, 2000,   90,   50,
#          90,  300,  500,  200,  900,   50,  300,   90,   50, 1000,   90,
#         200, 2000, 1000,   50,   50, 1500,  200,   50,  200, 2000, 1200,
#         200,  200,   50,   50,  200,   50,  600,  500,   50,   50, 1500,
#          50,  200,   90, 1200, 1000,  600,  200,   90,   90,  300,  500,
#         300,   50,  300,  200,  500,  600,  200,   50,   50,  600,   90,
#        1200,  500,  200,  300, 1500,  600,  200,   50,   50,   50,  200,
# ...

# %% [markdown]
# ### Checking the accuracy of the model

# %%
sklearn.metrics.accuracy_score(y_test, pred_clf)
# Out:
# 0.605

# %% [markdown]
# #### The svm classifier is doing a fairly good job at predicting the model

# %% [markdown]
# ### Generating a classification Building Report

# %%
sklearn.metrics.classification_report(y_test, pred_clf)
# Out:
# C:\Users\Alvin\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Alvin\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Alvin\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %%
print(sklearn.metrics.classification_report(y_test, pred_clf))
# Out:
#               precision    recall  f1-score   support
#
#           25       0.00      0.00      0.00        12
#           30       0.00      0.00      0.00         8
#           50       0.31      1.00      0.47        17
#           60       0.00      0.00      0.00         7
#           75       0.00      0.00      0.00         9
#           90       0.32      1.00      0.48         7
#          100       0.00      0.00      0.00        22
#          120       0.00      0.00      0.00        15
#          150       0.00      0.00      0.00         6
#          200       0.40      1.00      0.57        17
#          300       1.00      1.00      1.00        10
#          500       1.00      1.00      1.00        11
#          600       1.00      1.00      1.00         7
#          900       1.00      1.00      1.00        10
#         1000       1.00      1.00      1.00        11
#         1200       1.00      1.00      1.00        15
# ...

# %% [markdown]
# ### Using a Linear Regression Model

# %%
from sklearn.linear_model import LinearRegression

# %%
lr= LinearRegression()

# %%
lr.fit(X,y)
# Out:
# LinearRegression()

# %% [markdown]
# ### Predicting the Linear Regression Model

# %%
pred = lr.predict(X)

# %%
pred
# Out:
# array([ 217.95031587, 1163.98462991, -186.85250178,  986.54921506,
#          40.51490102, -186.85250178,  -21.90008392,  332.97074579,
#         664.6647504 ,  395.38573072,   40.51490102,  155.53533093,
#        1341.42004476,  345.45374277, 1518.85545962, 1341.42004476,
#         332.97074579,  -21.90008392,  -21.90008392,  842.10016526,
#         986.54921506,   40.51490102,  345.45374277,  487.22933555,
#        -136.92051383, 1163.98462991,  -21.90008392,  986.54921506,
#        -186.85250178,  842.10016526, 1019.53558011,  168.01832792,
#          40.51490102,  217.95031587,  842.10016526,  842.10016526,
#         155.53533093,  395.38573072,  345.45374277, -136.92051383,
#         -21.90008392,  842.10016526,  487.22933555, -199.33549877,
#        -186.85250178, 1019.53558011, 1341.42004476,  842.10016526,
#        1163.98462991,  155.53533093,  155.53533093,  487.22933555,
#          40.51490102, 1341.42004476,  345.45374277,  842.10016526,
# ...

# %% [markdown]
# ### Plotting a scatter plot for the Linear Model

# %%
plt.figure(figsize=(10,10))
plt.scatter(pred,y, s= 300, color ="red")
plt.xlabel("Predicted Values")
plt.ylabel("Total Amount")
plt.grid(True)
plt.title("Predicted Values vs Total Amount")
plt.show()

# %%
from sklearn.metrics import r2_score

# %%
r2_score(pred,y)
# Out:
# 0.8297946417173325

# %% [markdown]
# #### Conclusion: The linear regression model is a good fit
